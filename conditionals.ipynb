# %% [raw]
# Conditoional statements in python are used to make decisions in program.
# they allow the program to execute different
#
# they help the program choose what to do next based on a condition
#
# types
# 1. if
# 2. if else
# 3. if - elif - else
# 4. nested if else

# %% [raw]
# if syntax-
#
# if (cond):
#     print(statement)
# elif (cond) :
#     print()
# else:
#     print()

# %%
cit=input("enter your country ")
cit=cit.lower()
age=int(input("enter your age"))
if cit=="india" and age >= 18:
    print("you are eligible to vote")
elif cit=="india" and age<18:
    print("you are underaged")
else:
    print("not verified country")
# Out:
# enter your country  INDIA
# enter your age 34
# you are eligible to vote

# %%
num=int(input("enter any number"))
if num%2==0 :
    print("the number is even")
else:
    print("odd")
# Out:
# enter any number 20
# the number is even

# %%
per=int(input("enter your percentage"))
if per >=85 and per<=100:
    print("paased with distinction")
elif per>=60 and per<=84:
    print("first class")
elif per>=30 and per<=59:
    print("second class")
else:
    print("fail")
# Out:
# enter your percentage 56
# second class

# %% [raw]
# #Nested condtional statements:
#
# if(cond1):   #outer if
#     if(cond2):   #inner if
#         statements of inner if conditions
#     else:
#         statements of inner else
# else:
#     statements of outer else

# %%
num=int(input("enter a number"))
if num >=0:
    if num%2==0:
        print("even")
    else:
        print("odd")
else:
    print("negative number")
# Out:
# enter a number 40
# even

# %%
num=int(input("enter a number"))
if num!=0:
    if num>=0:
        print("+ve")
    else:
        print("-ve")
else:
    print("zero")
# Out:
# enter a number -2
# -ve

# %%
exp=float(input("enter your experience:"))
if exp>1:
    if exp>=10:
        print("outstanding")
    elif 5<=exp<10:
        print("excellent")
    else:
        print("moderate")
else:        
    print("frsher")
# Out:
# enter your experience: 2
# moderate

# %%
cs=float(input("enter your credit score:"))
if cs>600: 
    if cs>=800:
        print("low ins")
    elif cs<=700:
        print("med ins")    
    else:
        print("high")
else:
    print("rejected")
# Out:
# enter your credit score: 602
# med ins
