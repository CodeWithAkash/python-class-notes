# %% [raw]
# Errors :
# Errors are issues in the code that stop the program from running.
# They are usually caused by syntax mistakes or invalid code sturcture.
#
# Types of error:
# 1.Syntax error
#     occurs when python can't understand the code due to incorrect syntax.
# 2.Indentation error
#     python uses indentation to define blocks
#     wrong indentation causes errors
# 3.Logical error

# %%
print("hello")
# Out:
# hello

# %%
if True:
print("hello")
# Out:
#   Cell In[3], line 2
#     print("hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
34/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 34/0
#
# ZeroDivisionError: division by zero

# %%
for i in range(5,0,1):
    print(i)

#logical error

# %% [raw]
# Exceptions:
# exceptions are errors that occur while the program is running(runtime error) unlike syntax errors,
# the program runs until the exception occurs.

# %%
#zerodivsionError
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 #zerodivsionError
# ----> 2 10/0
#
# ZeroDivisionError: division by zero

# %%
#nameError
a=9
print(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #nameError
#       2 a=9
# ----> 3 print(j)
#
# NameError: name 'j' is not defined

# %%
print("2"+"2")
# Out:
# 22

# %%
print(2+2)
# Out:
# 4

# %%
print("2"+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print("2"+2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
n=int('abc')
n
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 n=int('abc')
#       2 n
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
m=str(234)
m
# Out:
# '234'

# %% [raw]
# Exception Handling:
# 1.Try-Except
#
#     syntax
#     try:
#         block of code
#     except:
#         error msg

# %%
try:
    n1=int(input("enter a num:"))
    n2=int(input("enter num2:"))
    m=n1/n2
    print(m)
except:
    n2==0
    print("number cannot  be divided by 0")
# Out:
# enter a num: 10
# enter num2: 0
# number cannot  be divided by 0

# %%
#catching specific error

try:
    a=int(input("enter a num:"))
    print(10/a)
except ZeroDivisionError:
    print("cannot divided by 0")
except ValueError:
    print("invalid value")
# Out:
# enter a num: 8
# 1.25

# %%
# !git add .

# %%
# !git commit -m "error handling file created")
# Out:
# [main d3a2633] error handling file created)
#  5 files changed, 550 insertions(+), 4 deletions(-)
#  create mode 100644 .ipynb_checkpoints/Error handling-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/sample-checkpoint.txt
#  create mode 100644 .ipynb_checkpoints/sample2-checkpoint.txt
#  create mode 100644 Error handling.ipynb

# %%
# !git push
# Out:
# To https://github.com/CodeWithAkash/python-class-notes.git
#    381833a..d3a2633  main -> main

# %%
try:
    b=int(input("enter a num:"))
    print(10/b)
except ZeroDivisionError:
    print("cannot divided by 0")
except ValueError:
    print("invalid value")
else:
    print("no error occured")
finally:
    print("execution is completed")
# Out:
# enter a num: 0
# cannot divided by 0
# execution is completed
