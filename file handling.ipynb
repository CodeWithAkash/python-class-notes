# %% [raw]
# File Handling:
# it allow us to create, read, write, update and delete files.
# it is used to store data permanently.
#
# the built-in function is open() to work with files
# common modes:
# 1. 'r' - read
# 2. 'w' - write
# 3. 'a' - append
# 4. 'b' - binary
# 5. 't' - text
# 6. 'rb' - read binary
# 7. 'wt' - write text
#
# File path:
#     1. Relative path- file name
#     2. Absolute path- directories(complete loc) + file name

# %%
d= open(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'r')
d.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d= open(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'r')
#       2 d.read()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\iamak\\OneDrive\\Documents\\Desktop\\demo.txt'

# %%
d.close()
d=open(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'w')
d.write("how are you ")
d.close()

# %%
d.read()

# %%
# !git add .

# %%
# !git commit -m "added new file named as file handling "

# %%
# !git push

# %%
s=open('sample.txt','r')
s.read()

# %%
s.close()

# %%
f=open(r"C:\Users\iamak\OneDrive\Documents\Desktop\Newdemo.txt",'w')

# %%
f.write("hi buddy")

# %%
f.close()

# %%
w=open("sample2.txt","w")
w.write("hello")

# %%
w.close()

# %%
d= open(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'a')
d.write("good afternoon")
d.close()

# %%
f= open(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'a')
f.write("good afternoon")
f.close()

# %%
f2=del(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt",'a')
f2.close()

# %%
import os
os.remove(r"C:\Users\iamak\OneDrive\Documents\Desktop\demo.txt")

# %%
import os 
os.remove("sample.txt")

# %%
import os 
os.remove(
