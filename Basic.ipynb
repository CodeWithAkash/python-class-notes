# %% [markdown]
# Python

# %% [raw]
# Variables:
# -its a value holder.
#
# Declaration format:
# -should not start with numbers
# -no space in-between
# -can contain alpha numericals values (mar3,ok4)
# -use underscores in-between (raw_man)
# -lower case, upper case both are acceptable
# -should not use keywords (and,or,if,etc)
# -no special characters can be used except underscores
#
#
# Data types:
# -it refers or respresent the type of data.
# -single value datatypes:
#   int
#   float
#   string
#   boolean
#   complex
# -multi value datatypes:
#   tuple
#   set
#   dictionary
#   list

# %%
#read a float value from user and convert it into integer

fl=float(input("enter a float value"))
fl=int(fl)
print(fl)
# Out:
# enter a float value 45.6
# 45

# %%
#wihtout using the same variable 

fl=round(float(input("enter a value")))
print(type(fl))
# Out:
# enter a value 54.678
# <class 'int'>

# %% [raw]
# Operators:
# special symbol perform certain operation between two operands
# ex: s =  3+4
#
# -arithmatic operators:  +  -  *  /  %  **  //
# -logical operators:  and  or  not
# -comparision/relational operators:  ==  !=  >  <  <=  >=
# -assignment operators:  =  +=  -=  *=  /=  %=  **=  //==
# -bitwise operators:  &  |  ~  >>  <<
# -membership operator:  in   not in
# -specail operators: is   is not

# %% [raw]
# write a program to read student name, id, email, 3 subject marks put of 100 and display there details in below format:
#
# *****Student Details*****
# ID:
# NAME:
# EMAIL:
# SUB1:
# SUB2:
# SUB3:
# TOTAL:
# PERCENTAGE:
#
# *****All the Best*****

# %%
name = input("Enter Student Name: ")
sid = input("Enter Student ID: ")
email = input("Enter Student Email: ")

sub1 = int(input("Enter Subject 1 Marks: "))
sub2 = int(input("Enter Subject 2 Marks: "))
sub3 = int(input("Enter Subject 3 Marks: "))

total = sub1 + sub2 + sub3
percentage = total / 3

print("*****Student Details*****\nID:", sid, "\nNAME:", name, "\nEMAIL:", email,
      "\nSUB1:", sub1, "\nSUB2:", sub2, "\nSUB3:", sub3,
      "\nTOTAL:", total, "\nPERCENTAGE:", percentage,
      "\n\n*****All the Best*****")
# Out:
# Enter Student Name:  asd
# Enter Student ID:  sadasd
# Enter Student Email:  asdds
# Enter Subject 1 Marks:  45
# Enter Subject 2 Marks:  3
# Enter Subject 3 Marks:  23
# *****Student Details*****
# ID: sadasd
# NAME: asd
# EMAIL: asdds
# SUB1: 45
# SUB2: 3
# SUB3: 23
# TOTAL: 71
# PERCENTAGE: 23.666666666666668
#
# *****All the Best*****

# %% [raw]
# 0101 -5
# 1100 -12
#
# 0100 -4
#
#
# 0010

# %%
3|20
# Out:
# 23

# %%
14>>2
# Out:
# 3

# %%
9<<2
# Out:
# 36

# %% [raw]
# write a program to swap 2 numbers
# 1) using with temp variable
# 2) without temp variable

# %%
#with temp var
a=5
b=6
print(a,b)
c=a,a=b,b=c
print(a,b)
# Out:
# 5 6
# 6 5

# %%
#without temp var
a=5
b=6
print(a,b)
a,b = b,a
print(a,b)
# Out:
# 5 6
# 6 5

# %%
str1 = 'My'
str2 = 'Name'
str3 = 'Is'
str4 = 'James'
print(str1,str2,str3,str4)
# Out:
# My Name Is James

# %%
num = 8
print(oct(num))
# Out:
# 0o10

# %%
num = 458.541315
print('%.2f'%num)
# Out:
# 458.54

# %%
num=[]
for i in range(0,5):
    print("enter the numbers")
    item=float(input())
    num.append(item)

print(num)
# Out:
# enter the numbers
#  45.6
# enter the numbers
#  23.67
# enter the numbers
#  67.8
# enter the numbers
#  45
# enter the numbers
#  34.6
# [45.6, 23.67, 67.8, 45.0, 34.6]
