# %%
#Create a NumPy array of 30 random sales values between 1000 and 5000 and calculate:
import numpy as np
sa=np.random.randint(1000,5001,30)
sa
# Out:
# array([2055, 2425, 3617, 3365, 4436, 2008, 2706, 3654, 2634, 1298, 1161,
#        4701, 1858, 1164, 4094, 3033, 1133, 3190, 1954, 4761, 4840, 1371,
#        2731, 1897, 4829, 4065, 4723, 4935, 2062, 2542], dtype=int32)

# %%
sa.sum()
# Out:
# np.int64(91556)

# %%
sa.mean()
# Out:
# np.float64(3051.866666666667)

# %%
sa.
